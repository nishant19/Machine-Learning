# %%
a=[1,2,3,1,2,3,1,2,3]

#Array slicing

a[4:8]  
#4th included, 8th index is not
#slicing of an array

a[2:] #from 2nd index till last
a[:4]  #from first index till the 3rd index
a[:]  #displays the whole array
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
import numpy as np
n= np.array(a)
n[1:3]
# Out:
# array([2, 3])

# %% [markdown]
# Machine learning is basically is using the past data, to predict the future. The machine learning algorithm decides what importance/ weight to be given to variour factors, while deciding answer,yes or no, eg: spam or not, based on the past data/results.
# eg: spam data- contact or not, spam keywords

# %% [markdown]
# CSV: A file with a format a,b,c,d .
#
# Pandas is a package.
# It is a much faster method for slicing an array, deleting rows/columns.

# %%
import pandas as pd
iris=pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data')

#iris is a dataset eg: titanic data set
#dataset can be accessed locally, or using a url

iris.head()  #gives first five rows of table ,generally   
             #iris.head(20) prints first 20     
#iris.tail()      #iris.tail(20) prints last 20

#no header, therefore 0th row isnt hown as header, indexing starts from ist row
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
iris.columns #to see only headings
iris.columns=['sl','sw','pl','pw','flower_class']   #to set new column names  #first tuple lost
iris.columns
#iris.head()
# Out:
# Index(['sl', 'sw', 'pl', 'pw', 'flower_class'], dtype='object')

# %%
iris.shape
# Out:
# (149, 5)

# %%
iris.dtypes
# Out:
# sl              float64
# sw              float64
# pl              float64
# pw              float64
# flower_class     object
# dtype: object

# %%
iris.describe()  #gives calculations about columns
# Out:
#                sl          sw          pl          pw
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
pd.isnull(iris)

#checks on every column of every row if there's a null and shows true or false

pd.isnull(iris).sum()  #columnwise sum of null values
# Out:
# sl              0
# sw              0
# pl              0
# pw              0
# flower_class    0
# dtype: int64

# %%
iris.sl # iris.columnName will give that column
# Out:
# 0      4.9
# 1      4.7
# 2      4.6
# 3      5.0
# 4      5.4
# 5      4.6
# 6      5.0
# 7      4.4
# 8      4.9
# 9      5.4
# 10     4.8
# 11     4.8
# 12     4.3
# 13     5.8
# 14     5.7
# 15     5.4
# 16     5.1
# 17     5.7
# 18     5.1
# 19     5.4
# 20     5.1
# 21     4.6
# 22     5.1
# 23     4.8
# 24     5.0
# 25     5.0
# 26     5.2
# 27     5.2
# 28     4.7
# 29     4.8
#       ...
# 119    6.9
# 120    5.6
# 121    7.7
# 122    6.3
# 123    6.7
# 124    7.2
# 125    6.2
# 126    6.1
# 127    6.4
# 128    7.2
# 129    7.4
# 130    7.9
# 131    6.4
# 132    6.3
# 133    6.1
# 134    7.7
# 135    6.3
# 136    6.4
# 137    6.0
# 138    6.9
# 139    6.7
# 140    6.9
# 141    5.8
# 142    6.8
# 143    6.7
# 144    6.7
# 145    6.3
# 146    6.5
# 147    6.2
# 148    5.9
# Name: sl, Length: 149, dtype: float64

# %%
iris.iloc[1:3,1:3]  #displays rows1,2 with columns 1,2
iris.iloc[0:1,:] #gives 0th row
# Out:
#     sl   sw   pl   pw flower_class
# 0  4.9  3.0  1.4  0.2  Iris-setosa

# %%
iris.sl.mean() #gives mean of column sl
iris.sl.sum()  #gives sum of column sl
# Out:
# 871.4000000000002

# %% [markdown]
# Pandas internally uses numpy

# %%
iris.iloc[1:3,1:2]=np.nan #puts null/nan values between specified indices
iris.head()
pd.isnull(iris)
# Out:
#         sl     sw     pl     pw  flower_class
# 0    False  False  False  False         False
# 1    False   True  False  False         False
# 2    False   True  False  False         False
# 3    False  False  False  False         False
# 4    False  False  False  False         False
# 5    False  False  False  False         False
# 6    False  False  False  False         False
# 7    False  False  False  False         False
# 8    False  False  False  False         False
# 9    False  False  False  False         False
# 10   False  False  False  False         False
# 11   False  False  False  False         False
# 12   False  False  False  False         False
# 13   False  False  False  False         False
# 14   False  False  False  False         False
# 15   False  False  False  False         False
# 16   False  False  False  False         False
# 17   False  False  False  False         False
# 18   False  False  False  False         False
# ...

# %%
iris.sw.fillna(1,inplace=True)
# fill null entries with 1 #inplace =True means changes made on the same table

iris.iloc[1:3,1:2]=np.nan
iris.sw.fillna(iris.sw.mean(),inplace=True) #fill null entries with sw column's mean
iris.head()
# Out:
#     sl       sw   pl   pw flower_class
# 0  4.9  3.00000  1.4  0.2  Iris-setosa
# 1  4.7  3.04966  1.3  0.2  Iris-setosa
# 2  4.6  3.04966  1.5  0.2  Iris-setosa
# 3  5.0  3.60000  1.4  0.2  Iris-setosa
# 4  5.4  3.90000  1.7  0.4  Iris-setosa

# %%
Y=iris['flower_class']
Y

del iris['flower_class'] #after first run, flower class already deleted

iris.head()
# Out:
#     sl       sw   pl   pw
# 0  4.9  3.00000  1.4  0.2
# 1  4.7  3.04966  1.3  0.2
# 2  4.6  3.04966  1.5  0.2
# 3  5.0  3.60000  1.4  0.2
# 4  5.4  3.90000  1.7  0.4

# %%
iris.iloc[1:3,:]=np.nan
iris.dropna(inplace=True)  #removes rows with column values null/NaN   #inplace=tRUE means make changes on same table
iris.head()
# Out:
#     sl   sw   pl   pw
# 0  4.9  3.0  1.4  0.2
# 3  5.0  3.6  1.4  0.2
# 4  5.4  3.9  1.7  0.4
# 5  4.6  3.4  1.4  0.3
# 6  5.0  3.4  1.5  0.2

# %%
iris.reset_index()
a=iris.reset_index()
a
#iris.head()
# Out:
#      index   sl   sw   pl   pw
# 0        0  4.9  3.0  1.4  0.2
# 1        3  5.0  3.6  1.4  0.2
# 2        4  5.4  3.9  1.7  0.4
# 3        5  4.6  3.4  1.4  0.3
# 4        6  5.0  3.4  1.5  0.2
# 5        7  4.4  2.9  1.4  0.2
# 6        8  4.9  3.1  1.5  0.1
# 7        9  5.4  3.7  1.5  0.2
# 8       10  4.8  3.4  1.6  0.2
# 9       11  4.8  3.0  1.4  0.1
# 10      12  4.3  3.0  1.1  0.1
# 11      13  5.8  4.0  1.2  0.2
# 12      14  5.7  4.4  1.5  0.4
# 13      15  5.4  3.9  1.3  0.4
# 14      16  5.1  3.5  1.4  0.3
# 15      17  5.7  3.8  1.7  0.3
# 16      18  5.1  3.8  1.5  0.3
# 17      19  5.4  3.4  1.7  0.2
# 18      20  5.1  3.7  1.5  0.4
# 19      21  4.6  3.6  1.0  0.2
# 20      22  5.1  3.3  1.7  0.5
# 21      23  4.8  3.4  1.9  0.2
# 22      24  5.0  3.0  1.6  0.2
# 23      25  5.0  3.4  1.6  0.4
# 24      26  5.2  3.5  1.5  0.2
# 25      27  5.2  3.4  1.4  0.2
# 26      28  4.7  3.2  1.6  0.2
# 27      29  4.8  3.1  1.6  0.2
# 28      30  5.4  3.4  1.5  0.4
# ...

# %%
iris.reset_index(drop=True,inplace=True)  #drops extra column now created after reset_index
iris.head()
# Out:
#     sl   sw   pl   pw
# 0  4.9  3.0  1.4  0.2
# 1  5.0  3.6  1.4  0.2
# 2  5.4  3.9  1.7  0.4
# 3  4.6  3.4  1.4  0.3
# 4  5.0  3.4  1.5  0.2

# %% [markdown]
# Package for plotting  - Matplotlib

# %%
import matplotlib.pyplot as plt
# we need only pyplot of matplotlib package

from matplotlib import style

# %%
x=[1,2,3]
y=[3,6,12]
plt.plot(x,y)  #plots , join lines between points
plt.show()   #shows plotting
plt.title("demo")  #gives title
plt.xlabel("X") #gives name to x axis
plt.ylabel("Y")  #gives name to y axis
#plt.show()
plt.scatter(x,y)
plt.show()#only plots points, does not join them

# %%
plt.plot(x,y,label="value1",linewidth=5)
x2=[16,2,23]
y2=[8,9,10]
plt.plot(x2,y2,label="value2")
plt.legend()   # to display values of labels
plt.show()

# %%
# styles 
style.use('ggplot')
plt.plot(x2,y2,label="value4",linewidth=10)
plt.legend()
plt.show()

# %%
# bar graphs for x,y
plt.bar(x,y,color='b')
plt.show()

# %%
#Histogram

print(np.random.randn(100))   #distribution with mean 0
a=20+np.random.randn(10000)  #distribution around 20 
plt.hist(a,14)   #number of buckets=20
plt.show()
# Out:
# [-0.98847657  1.48272272  0.24855635  0.34882776 -2.41993986  1.28614497
#  -0.35198079  1.45778382 -0.37731418 -0.75569137 -0.4558168  -0.60070586
#  -0.10510761  0.35572832 -2.07678959 -0.09425074 -0.21502386 -1.10329443
#   0.09214759 -0.43396897  1.43417189  0.922048    0.50991356  0.50540841
#  -0.32870953 -0.24064003 -0.22561382 -0.18406497  0.79550027 -2.18919741
#   0.03420214 -0.12184414  0.48246059  0.24202473  0.80892383  0.5419859
#  -1.65548279  1.26920321  0.47333266  0.40474102 -0.21756686 -1.96098456
#   0.56806752 -0.25829622  0.64162593 -1.45911995 -1.11374549  1.05505986
#  -0.33287637 -1.31563525  0.55489258 -0.03550827  0.14492843 -0.92972239
#  -0.64229629 -0.45223477  0.03064814  1.01481156 -1.1530325  -0.36928735
#  -0.86685923 -0.8854479  -0.18807158  1.27738335 -0.55154702  0.7052858
#   0.1529779  -0.21414453 -0.88058108 -0.56889844 -2.92354528 -0.83064255
#   0.61146263 -0.49062684 -1.99336963  1.44153767 -0.63956184  0.02080427
# ...

# %%
titanic=pd.read_csv('titanic_train.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
del titanic['PassengerId']
titanic.head()
del titanic['Name']

# %%
#checking number of null entries in cabin column
pd.isnull(titanic['Cabin']).sum()
titanic.shape
# Out:
# (891, 10)

# %%
pd.isnull(titanic).sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
del titanic['Cabin']

# %%
titanic.head()
titanic['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
# 5      0
# 6      0
# 7      0
# 8      1
# 9      1
# 10     1
# 11     1
# 12     0
# 13     0
# 14     0
# 15     1
# 16     0
# 17     1
# 18     0
# 19     1
# 20     0
# 21     1
# 22     1
# 23     1
# 24     0
# 25     1
# 26     0
# 27     0
# 28     1
# 29     0
#       ..
# 861    0
# 862    1
# 863    0
# 864    0
# 865    1
# 866    1
# 867    0
# 868    0
# 869    1
# 870    0
# 871    1
# 872    0
# 873    0
# 874    1
# 875    1
# 876    0
# 877    0
# 878    0
# 879    1
# 880    1
# 881    0
# 882    0
# 883    0
# 884    0
# 885    0
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
titanic.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic[titanic.Survived==1].describe()
meanS=titanic[titanic.Survived==1].Age.mean()


meanS
# Out:
# 28.343689655172415

# %%
titanic[titanic.Survived==1].Age.fillna(meanS, inplace=True)
pd.isnull(titanic.Survived==1).sum()
# Out:
# /Users/admin/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:3549: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# 0

# %%
meanNS=titanic[titanic.Survived==0].Age.mean()
meanNS#changes are not made to titanic but a different object
# Out:
# 30.62617924528302

# %%
titanic['Embarked'].dropna(inplace=True)
pd.isnull(titanic).sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Embarked      2
# dtype: int64

# %%
def getNumber(str):
    if str=='male':
        return 1
    else:
        return 2
    
titanic['gender']=titanic['Sex'].apply(getNumber)
titanic.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0         0       3    male  22.0      1      0         A/5 21171   7.2500
# 1         1       1  female  38.0      1      0          PC 17599  71.2833
# 2         1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3         1       1  female  35.0      1      0            113803  53.1000
# 4         0       3    male  35.0      0      0            373450   8.0500
#
#   Embarked  gender
# 0        S       1
# 1        C       2
# 2        S       2
# 3        S       2
# 4        S       1

# %%
del titanic['Sex']
titanic.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch            Ticket     Fare Embarked  \
# 0         0       3  22.0      1      0         A/5 21171   7.2500        S
# 1         1       1  38.0      1      0          PC 17599  71.2833        C
# 2         1       3  26.0      0      0  STON/O2. 3101282   7.9250        S
# 3         1       1  35.0      1      0            113803  53.1000        S
# 4         0       3  35.0      0      0            373450   8.0500        S
#
#    gender
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1

# %%
t=titanic[titanic.Embarked!=np.nan]
pd.isnull(t).sum()

#titanic
pd.isnull(titanic).sum()
# Out:
# Survived      0
# Pclass        0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Embarked      2
# gender        0
# dtype: int64

# %%
titanic.loc[titanic['Age'].isnull() & titanic['Survived']==0,'Age']=30  # did not work
titanic.loc[titanic['Age'].isnull() & titanic['Survived']==1,'Age']=28 # did not work

# %%
titanic.head(50)
# Out:
#     Survived  Pclass   Age  SibSp  Parch            Ticket      Fare Embarked  \
# 0          0       3  22.0      1      0         A/5 21171    7.2500        S
# 1          1       1  38.0      1      0          PC 17599   71.2833        C
# 2          1       3  26.0      0      0  STON/O2. 3101282    7.9250        S
# 3          1       1  35.0      1      0            113803   53.1000        S
# 4          0       3  35.0      0      0            373450    8.0500        S
# 5          0       3   NaN      0      0            330877    8.4583        Q
# 6          0       1  54.0      0      0             17463   51.8625        S
# 7          0       3   2.0      3      1            349909   21.0750        S
# 8          1       3  27.0      0      2            347742   11.1333        S
# 9          1       2  14.0      1      0            237736   30.0708        C
# 10         1       3   4.0      1      1           PP 9549   16.7000        S
# ...

# %%
#titanic.loc[titanic['Age'].isnull() & titanic['Survived']==0,'Age']=meanNS

# %%
#titanic.head(50)

# %%
pd.isnull(titanic).sum()
# Out:
# Survived     0
# Pclass       0
# Sex          0
# Age         52
# SibSp        0
# Parch        0
# Ticket       0
# Fare         0
# Embarked     2
# gender       0
# dtype: int64

# %%
titanic.dropna(inplace=True)
pd.isnull(titanic).sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    0
# gender      0
# dtype: int64

# %%
survivedS=titanic[titanic.Survived==1][titanic.Embarked=='C'].shape[0]
survivedS   

#PORT Q, SURVIVED=30 notsurvived=47
  
#PORT S, SURVIVED=217 notsurvived=427 
#PORT C, SURVIVED =93 notsurvived=75
#Therefore, port is an important factor
# Out:
# /Users/admin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 93

# %%
titanic.head(50)
# Out:
#     Survived  Pclass     Sex   Age  SibSp  Parch            Ticket      Fare  \
# 0          0       3    male  30.0      1      0         A/5 21171    7.2500
# 1          1       1  female  30.0      1      0          PC 17599   71.2833
# 2          1       3  female  30.0      0      0  STON/O2. 3101282    7.9250
# 3          1       1  female  30.0      1      0            113803   53.1000
# 4          0       3    male  30.0      0      0            373450    8.0500
# 5          0       3    male  30.0      0      0            330877    8.4583
# 6          0       1    male  30.0      0      0             17463   51.8625
# 7          0       3    male  30.0      3      1            349909   21.0750
# 8          1       3  female  30.0      0      2            347742   11.1333
# 9          1       2  female  30.0      1      0            237736   30.0708
# 10         1       3  female  30.0      1      1           PP 9549   16.7000
# ...

# %%
titanic["age"]=np.where(titanic['Age'].isnull() & titanic['Survived']==1,meanS,titanic['Age'])  
titanic["age"].fillna(meanNS,inplace=True)

# PROBLEM SOLVED 

# putting mean values of survived column to null values of survived column

#titanic["age"]=np.where(titanic['Age'].isnull() & titanic['Survived']==0,meanNS,titanic['Age'] )    #ERROR??   #WTFFF

titanic.head(30)

# del titanic['Age']
# Out:
#     Survived  Pclass   Age  SibSp  Parch            Ticket      Fare Embarked  \
# 0          0       3  22.0      1      0         A/5 21171    7.2500        S
# 1          1       1  38.0      1      0          PC 17599   71.2833        C
# 2          1       3  26.0      0      0  STON/O2. 3101282    7.9250        S
# 3          1       1  35.0      1      0            113803   53.1000        S
# 4          0       3  35.0      0      0            373450    8.0500        S
# 5          0       3   NaN      0      0            330877    8.4583        Q
# 6          0       1  54.0      0      0             17463   51.8625        S
# 7          0       3   2.0      3      1            349909   21.0750        S
# 8          1       3  27.0      0      2            347742   11.1333        S
# 9          1       2  14.0      1      0            237736   30.0708        C
# 10         1       3   4.0      1      1           PP 9549   16.7000        S
# ...
